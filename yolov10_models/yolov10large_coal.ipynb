# %%
from ultralytics import YOLO
import torch
import os
from IPython import display
from PIL import Image
# %matplotlib inline

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# Load a model
model = YOLO("yolov10m.pt")  # build a new model from scratch

# %%
model = model.to(device)

# %%
model.info()
# Out:
# YOLOv10m summary: 498 layers, 16,576,768 parameters, 0 gradients, 64.5 GFLOPs
# (498, 16576768, 0, 64.4772096)

# %%
train_results = model.train(
    data='/home/kambhamettu.s/Projects/mining/models/yolov10_models/data3.yaml',  # path to dataset YAML
    epochs=100,   # number of training epochs
    batch = 12,  
    imgsz=640,  # training image size
    device=device,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.14 torch-2.4.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32501MiB)
# ...

# %%
test_img = "/home/kambhamettu.s/Projects/mining/large_coal_data2023_yolo/images/val/2-28.jpg"

# %%
import cv2
import matplotlib.pyplot as plt

# Load your test image
test_img = test_img  # Replace with your image path
image = cv2.imread(test_img)

# Perform object detection on the image
results = model(test_img)

# Get the output image with detections
output_image = results[0].plot()  # Create a plot with detections
# Out:
# image 1/1 /home/kambhamettu.s/Projects/mining/large_coal_data2023_yolo/images/val/2-28.jpg: 384x640 4 large_coals, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Resize the image for better display (optional)
output_image = cv2.resize(output_image, (800, 600))  # Resize to 800x600

# Convert the image from BGR to RGB
output_image = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)

# %%
# Plot the image
plt.figure(figsize=(10, 8))
plt.imshow(output_image)
plt.axis('off')  # Turn off axis
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Set the image path
img_path = "/home/kambhamettu.s/Projects/mining/models/yolov10_models/runs/detect/train5/confusion_matrix_normalized.png"  # Replace with your image path

# Load the image
img = mpimg.imread(img_path)

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Set the image path
img_path = "/home/kambhamettu.s/Projects/mining/models/yolov10_models/runs/detect/train5/F1_curve.png"  # Replace with your image path

# Load the image
img = mpimg.imread(img_path)

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Set the image path
img_path = "/home/kambhamettu.s/Projects/mining/models/yolov10_models/runs/detect/train5/results.png"  # Replace with your image path

# Load the image
img = mpimg.imread(img_path)

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Set the image path
img_path = "/home/kambhamettu.s/Projects/mining/models/yolov10_models/runs/detect/train5/val_batch2_pred.jpg"  # Replace with your image path

# Load the image
img = mpimg.imread(img_path)

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()
