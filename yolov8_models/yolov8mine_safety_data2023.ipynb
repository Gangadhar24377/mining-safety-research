# %%
from ultralytics import YOLO
import torch
import os
from IPython import display
from PIL import Image
# %matplotlib inline

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# %pwd
# Out:
# '/home/kambhamettu.s/Projects/mining/models/yolov8_models'

# %%
# %cd /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo
# Out:
# /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo
# /home/kambhamettu.s/.conda/envs/mining/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt").to(device)

# %%
model.train(
    data="/home/kambhamettu.s/Projects/mining/models/yolov8_models/data4.yaml",
    epochs=100,
    batch=16,
    imgsz=640,
    device=device,
    optimizer="AdamW",  # Better for convergence
    lr0=0.001,  # Reduce learning rate
    weight_decay=0.0001,  # Reduce overfitting
    augment=True,
    mosaic=1.0,
    mixup=0.1
)
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.14 torch-2.4.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32501MiB)
# ...

# %%
results = model.val()
print(results)
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.14 torch-2.4.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32501MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/labels/val.cache... 1000 images, 4 backgrounds, 0 corrupt: 100%|██████████| 1000/1000 [00:00<?, ?it/s]
# /home/kambhamettu.s/.conda/envs/mining/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
test_img = "/home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/images/val/0008872.jpg"

# %%
# Perform object detection on an image
results = model(test_img)
results[0].show()
# Out:
# image 1/1 /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/images/val/0008872.jpg: 384x640 1 mine_safety, 159.7ms
# Speed: 3.7ms preprocess, 159.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# %pwd
# Out:
# '/home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo'

# %%
import cv2
import matplotlib.pyplot as plt

# Load your test image
test_img = test_img  # Replace with your image path
image = cv2.imread(test_img)

# Perform object detection on the image
results = model(test_img)

# Get the output image with detections
output_image = results[0].plot()  # Create a plot with detections
# Out:
# image 1/1 /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/images/val/0008872.jpg: 384x640 1 mine_safety, 47.1ms
# Speed: 5.3ms preprocess, 47.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Resize the image for better display (optional)
output_image = cv2.resize(output_image, (800, 600))  # Resize to 800x600

# Convert the image from BGR to RGB
output_image = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)

# %%
# Plot the image
plt.figure(figsize=(10, 8))
plt.imshow(output_image)
plt.axis('off')  # Turn off axis
plt.show()

# %%
# %cd /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/runs/detect/train5
# Out:
# /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo/runs/detect/train5
# /home/kambhamettu.s/.conda/envs/mining/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img_path = test_img  # Replace with your image path
img = mpimg.imread("confusion_matrix.png")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img_path = test_img  # Replace with your image path
img = mpimg.imread("F1_curve.png")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img_path = test_img  # Replace with your image path
img = mpimg.imread("results.png")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img_path = test_img  # Replace with your image path
img = mpimg.imread("val_batch0_pred.jpg")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Displayed Image')
plt.show()

# %%
# %cd /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo
# Out:
# /home/kambhamettu.s/Projects/mining/mine_safety_data2023_yolo

# %%
# Save the model
model.save('model4m.pt')
